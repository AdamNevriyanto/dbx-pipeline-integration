# %%
dbutils.library.restartPython()

# %%
import pandas as pd
import pyspark.sql.functions as timestamp

# %%
pdf = pd.read_csv("/Workspace/Users/jeremi.santoso@metrodata.co.id/test_btn/raw/CFMAST.csv")

# convert ke Spark DataFrame
df = spark.createDataFrame(pdf)

# %%
catalog_name   = "mii_workspace"
schema_name    = "default"
table_name     = "bronze_customer"
raw_folder     = "/Workspace/Users/jeremi.santoso@metrodata.co.id/test_btn/raw"
file_pattern   = "*.csv" 

# KONFIG TABLE dan PATH RAW
table_name     = f"{catalog_name}.{schema_name}.{table_name}"
raw_path       = f"{raw_folder}/{file_pattern}"

# %%
# READ RAW CSV
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(raw_path)
df = df.withColumn("ingested_timestamp", F.current_timestamp())
# df.display()

WRITE TO CATALOG
df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable(table_name)

print(f"Data Successfully ingested to Table : {table_name}")
